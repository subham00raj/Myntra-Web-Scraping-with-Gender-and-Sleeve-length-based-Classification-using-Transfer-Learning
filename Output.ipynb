# %%
import os
import requests
from tqdm import tqdm, trange
import pandas as pd
import tensorflow as tf
import scraper

# %% [markdown]
# ## Data Scraping

# %%
work_dir = '/Users/subhamraj/Desktop/Timble/'

# %%
df1 = scraper.scrape_myntra(product = 'Half Sleeve Men T-shirt', num_pages = 5)
scraper.save_image(work_dir, 'half_men', df1)
# Out:
# ...
# Saving Images: 100%|██████████| 250/250 [05:48<00:00,  1.39s/ images]

# %%
df2 = scraper.scrape_myntra(product = 'Full Sleeve Men T-shirt', num_pages = 5)
scraper.save_image(work_dir, 'full_men', df2)
# Out:
# ...
# Saving Images: 100%|██████████| 250/250 [05:50<00:00,  1.40s/ images]

# %%
df3 = scraper.scrape_myntra(product = 'Half Sleeve Women T-shirt', num_pages = 5)
scraper.save_image(work_dir, 'half_women', df3)
# Out:
# ...
# Saving Images: 100%|██████████| 250/250 [05:57<00:00,  1.43s/ images]

# %%
df4 = scraper.scrape_myntra(product = 'Full Sleeve Women T-shirt', num_pages = 5)
scraper.save_image(work_dir, 'full_women', df4)
# Out:
# ...
# Saving Images: 100%|██████████| 250/250 [05:56<00:00,  1.42s/ images]

# %% [markdown]
# ## Prediction

# %%
gender_model = tf.keras.models.load_model('gender.h5')
sleeve_model = model = tf.keras.models.load_model('Sleeve_Classifier.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
directory = '/Users/subhamraj/Desktop/Timble/test_sample'
for file in os.listdir(directory):
    path = directory + '/' + file
    print(scraper.predict(path, gender_model, sleeve_model),end='')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# None
